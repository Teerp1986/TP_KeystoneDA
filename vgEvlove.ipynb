# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# What is the Highest Grossing Genre of Gaming Globally?
# Who was the highest grossing Game publisher?
# Which platform produces the highest grossing games?
# Which Game produced the most Global Revenue?
#Which country has made the most revenue in video gaming between Japan, North America, and Europe?

# %%
df_vgsales2 = pd.read_csv('Data/vgsales2.csv')
df_vgsales2
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_vgsales2.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df_vgsales2.isna()  
df_vgsales2.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df_vgsales2.loc[df_vgsales2['Publisher'].isna()]# Checking for null values in 'Publisher' column
# Out:
#         Rank                                               Name Platform  \
# 470      471                         wwe Smackdown vs. Raw 2006      PS2
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %%
df_vgsales2.duplicated(keep=False).sum()# Checking for duplicate rows
# Out:
# np.int64(0)

# %%
df_vgsales2.loc[df_vgsales2['Platform'].duplicated(keep=False)].sort_values('Platform')# Displaying duplicate rows based on 'Platform' column
# Out:
#         Rank                                               Name Platform  \
# 8757    8759                                               Klax     2600
# 4139    4141                                         Grand Prix     2600
# 4469    4471                                     Super Breakout     2600
# 3716    3718                                       Action Force     2600
# 5798    5800                                       Slot Machine     2600
# ...      ...                                                ...      ...
# 193      194                     Call of Duty: Advanced Warfare     XOne
# 15153  15156                               Rugby World Cup 2015     XOne
# 14186  14188  Teenage Mutant Ninja Turtles: Mutants in Manha...     XOne
# 3359    3361                                 Tomb Raider (2013)     XOne
# 2554    2556                                        Dying Light     XOne
#
#          Year    Genre                               Publisher  NA_Sales  \
# ...

# %%
df_vgsales2_corr = df_vgsales2[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].corr()

# %%
df_vgsales2.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# Convert 'Year' column to integer type, filling NaN with 1909. 
# Removed the decimal number in "Year" values.

df_vgsales2 = df_vgsales2.astype({'Year':'float64'})

df_vgsales2['Year'] = df_vgsales2['Year'].fillna('1909')

# %%
df_vgsales2.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
df_vgsales2 = df_vgsales2.astype({'Year':'int64'})

df_vgsales2['Year'] = df_vgsales2['Year'].fillna(1909)

# %%
df_vgsales2.drop(columns=['Other_Sales'], inplace=True)

# %%
df_vgsales2.head(10)
# Out:
#    Rank                       Name Platform  Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Global_Sales
# 0     41.49     29.02      3.77         82.74
# 1     29.08      3.58      6.81         40.24
# ...

# %%
df_vgsales2.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df_vgsales2.rename(columns={'Name':'Game', 'NA_Sales':'North America', 'EU_Sales':'Europe', 'JP_Sales':'Japan'}, inplace=True)

# %%
df_vgsales2.head(10)
# Out:
#    Rank                       Game Platform  Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984       Shooter  Nintendo
#
#    North America  Europe  Japan  Global_Sales
# 0          41.49   29.02   3.77         82.74
# 1          29.08    3.58   6.81         40.24
# ...

# %%
# What is the Highest Grossing Genre of Gaming Globally?
sorted_df_vgsales2 = df_vgsales2.sort_values(by=['Genre'], ascending=False) 
Top_10_Genre = sorted_df_vgsales2.head(10)
Top_10_Genre
# Out:
#         Rank                                               Game Platform  \
# 11820  11822                                         Kessen III      PS2
# 806      808                            Warcraft: Orcs & Humans       PC
# 2133    2135                                        Fire Emblem      GBA
# 11703  11705               Tears to Tiara: Garland of the Earth      PS3
# 11699  11701           P.T.O. IV: Pacific Theater of Operations      PS2
# 11692  11694                  Stella Deus: The Gate of Eternity      PS2
# 11678  11680  The Lord of the Rings: The Battle for Middle-E...       PC
# 11677  11679                                          Quo Vadis      SAT
# 11671  11673             Dragon Force II: Kamisarishi Daichi ni      SAT
# 4992    4994                     SD Gundam G Generation Spirits      PS2
#
#        Year     Genre           Publisher  North America  Europe  Japan  \
# 11820  2004  Strategy          Tecmo Koei           0.04    0.03   0.00
# ...

# %%
Genre= df_vgsales2.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
colors = ["#959f99"]*len(Genre)# Create a list of colors for the bars

max_index = Genre.idxmax() 
highlight_position = Genre.index.get_loc(max_index)
colors[highlight_position] = "#17bf39" 

plt.bar(Genre.index, Genre.values, color = colors, width = 0.8) 
ax = plt.gca() # Get the current axes object
ax.spines['top'].set_visible(False) # Remove the top spine
ax.spines['right'].set_visible(False) # Remove the right spine


plt.xlabel("Genre")# Add a label for the x-axis
plt.ylabel("Global Sales (Millions)")# Add a label for the y-axis
plt.title("Highest Grossing Genre in Gaming Globally")# Add a title to the chart
plt.xticks(rotation=45, ha="right")# Rotate x-axis labels for better readability

plt.tight_layout() # Adjust layout to prevent clipping of tick-labels
plt.show()

# %%
#Who are the Top 10 Highest Grossing Game Publishers?
sorted_df_vgsales2 = df_vgsales2.sort_values(by=['Publisher'], ascending=False) 
Publisher = sorted_df_vgsales2.head(10)
Publisher
# Out:
#         Rank                                               Game Platform  \
# 13684  13686                                   Yourself Fitness      PS2
# 10945  10947                                   Yourself Fitness       XB
# 2409    2411                                 Monster Strike 3DS      3DS
# 10756  10758                                        Wasteland 2       PC
# 14259  14262                                      Toushin Toshi      3DS
# 16423  16426                                            SoniPro      3DS
# 14599  14602                                               Doom       PC
# 12244  12246                           Jewel Quest IV: Heritage       DS
# 15270  15273  World Neverland 2in1 Portable: Olerud Kingdom ...      PSP
# 14432  14435                         Alia's Carnival! Sacrament      PSV
#
#        Year         Genre             Publisher  North America  Europe  Japan  \
# 13684  2005        Sports          responDESIGN           0.02    0.02   0.00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group, sum, sort, and select top 10 publishers
publishers_sales = (
    df_vgsales2.groupby("Publisher")["Global_Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

plt.figure(figsize=(12, 7))

# Horizontal bar chart
plt.barh(
    publishers_sales["Publisher"],
    publishers_sales["Global_Sales"],
    color="#4C72B0"
)

plt.title("Top 10 Highest Grossing Game Publishers", fontsize=16)
plt.xlabel("Global Sales (Millions)", fontsize=12)
plt.ylabel("Publisher", fontsize=12)

# Highest value at the top
plt.gca().invert_yaxis()

plt.grid(axis="x", linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# Which platforms produce the highest grossing games in multiple regions
Platform_sales = df_vgsales2.groupby("Platform")["Global_Sales"].sum().sort_values(ascending=False).head(10).reset_index()
Platform_sales
# Out:
#   Platform  Global_Sales
# 0      PS2       1255.64
# 1     X360        979.96
# 2      PS3        957.84
# 3      Wii        926.71
# 4       DS        822.49
# 5       PS        730.66
# 6      GBA        318.50
# 7      PSP        296.28
# 8      PS4        278.10
# 9       PC        258.82

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_vgsales2 = pd.read_csv("Data/vgsales2.csv")

# Create top 10 for each region
global_sales = (
    df_vgsales2.groupby("Platform")["Global_Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

na_sales = (
    df_vgsales2.groupby("Platform")["NA_Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

jp_sales = (
    df_vgsales2.groupby("Platform")["JP_Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

eu_sales = (
    df_vgsales2.groupby("Platform")["EU_Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# --- 1. Global: Bar Chart ---
axes[0, 0].bar(global_sales["Platform"], global_sales["Global_Sales"], color="#4C72B0")
axes[0, 0].set_title("Top 10 Platforms – Global Sales (Bar Chart)")
axes[0, 0].tick_params(axis="x", rotation=45)

# --- 2. North America: Scatter Plot ---
axes[0, 1].scatter(na_sales["Platform"], na_sales["NA_Sales"], color="#589B4B", s=120)
axes[0, 1].set_title("Top 10 Platforms – North America (Scatter Plot)")
axes[0, 1].tick_params(axis="x", rotation=45)

# --- 3. Japan: Line Plot ---
axes[1, 0].plot(jp_sales["Platform"], jp_sales["JP_Sales"], marker="o", color="#D95F02")
axes[1, 0].set_title("Top 10 Platforms – Japan (Line Plot)")
axes[1, 0].tick_params(axis="x", rotation=45)

# --- 4. Europe: Horizontal Bar Chart ---
axes[1, 1].barh(eu_sales["Platform"], eu_sales["EU_Sales"], color="#9467BD")
axes[1, 1].set_title("Top 10 Platforms – Europe (Horizontal Bar Chart)")
axes[1, 1].invert_yaxis()  # Highest at top

plt.tight_layout()
plt.show()

# %%
#Which Game produced the most Global Revenue?
sorted_df_vgsales2 = df_vgsales2.sort_values(by=['Global_Sales'], ascending=False) 
Global_Sales = sorted_df_vgsales2.head(10)
Global_Sales
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df_vgsales2.rename(columns={'Name':'Game', 'NA_Sales':'North America', 'EU_Sales':'Europe', 'JP_Sales':'Japan'}, inplace=True)

# %%
df_vgsales2.columns[1]
# Out:
# 'Game'

# %%
sorted_df_vgsales2 = df_vgsales2.sort_values(by=['Global_Sales'], ascending=False)
Global_Sales = sorted_df_vgsales2.head(10)

# %%
Global_Sales.iloc[1]
Global_Sales['Game']
# Out:
# 0                   Wii Sports
# 1            Super Mario Bros.
# 2               Mario Kart Wii
# 3            Wii Sports Resort
# 4     Pokemon Red/Pokemon Blue
# 5                       Tetris
# 6        New Super Mario Bros.
# 7                     Wii Play
# 8    New Super Mario Bros. Wii
# 9                    Duck Hunt
# Name: Game, dtype: object

# %%
# Out:
# ['Wii', 'NES', 'Wii', 'Wii', 'GB', 'GB', 'DS', 'Wii', 'Wii', 'NES']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sort and select top 10 games by Global Sales
sorted_df_vgsales2 = df_vgsales2.sort_values(by=['Global_Sales'], ascending=False)
Global_Sales = sorted_df_vgsales2.head(10)

# Set the Game column as the index so it appears on the y-axis
Global_Sales = Global_Sales.set_index("Game")

# Create heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(
    Global_Sales[['Global_Sales']],
    annot=True,
    cmap='YlOrRd',
    linewidths=.5,
    fmt=".2f"
)

plt.title("Top 10 Games by Global Revenue (Heatmap)")
plt.ylabel("Game Title")
plt.xlabel("Global Sales (Millions)")
plt.show()

# %%
#Which country has made the most revenue in video gaming between Japan, North America, and Europe?

# Sum total sales by region
na_sales = df_vgsales2["North America"].sum()
eu_sales = df_vgsales2["Europe"].sum()
jp_sales = df_vgsales2["Japan"].sum()

# Create a summary DataFrame
region_sales = pd.DataFrame({
    "Region": ["North America", "Europe", "Japan"],
    "Total Sales (Millions)": [na_sales, eu_sales, jp_sales]
})

# Sort by revenue
region_sales = region_sales.sort_values(by="Total Sales (Millions)", ascending=False)

# Display result
print(region_sales.head())

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
#           Region  Total Sales (Millions)
# 0  North America                 4392.95
# 1         Europe                 2434.13
# 2          Japan                 1291.02

# %%
import matplotlib.pyplot as plt

# Sum total sales by region
na_sales = df_vgsales2["North America"].sum()
eu_sales = df_vgsales2["Europe"].sum()
jp_sales = df_vgsales2["Japan"].sum()

# Labels and values
regions = ["North America", "Europe", "Japan"]
sales = [na_sales, eu_sales, jp_sales]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    sales,
    labels=regions,
    autopct="%1.1f%%",
    startangle=140,
    colors=["#db0a0a", "#66b3ff", "#99ff99"]
)

plt.title("Total Video Game Revenue by Region")
plt.show()
